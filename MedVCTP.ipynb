# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-matsumoto74/image_cnn_v1/blob/vit/MedVCTP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Carrote-s/MedVCTP.git
# Out:
# Cloning into 'MedVCTP'...
# remote: Enumerating objects: 321, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 321 (delta 29), reused 11 (delta 11), pack-reused 280 (from 2)
# Receiving objects: 100% (321/321), 304.88 KiB | 1.81 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# %cd MedVCTP
# Out:
# /content/MedVCTP

# %%
# !ls
# Out:
#  close_bbox.json	 Load_Llama3.1.py     raw_images.json
#  FewShotExamples.py	 loadmedgemma.py      raw_images_with_bbox_new.json
#  Functions_Ablation.py	 Load_SLAKE.py	      rCaptions1_0.json
#  Functions_MedVCTP.py	 MedgemmaConfig.py    README.md
# 'gCaptions_0 (1).json'	 medGemmaPrompts.md   Run_Ablation.py
#  llamaprompts.md	 MedVCTP.ipynb	      Run_MedVCTP.py
#  Load_BioMedCLIP.py	 MedVCTP.py	      VQARAD.ipynb

# %%
# !pip install --upgrade "huggingface_hub[cli]"
# Out:
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Collecting huggingface_hub[cli]
#   Downloading huggingface_hub-1.16.1-py3-none-any.whl.metadata (14 kB)
# WARNING: huggingface-hub 1.16.1 does not provide the extra 'cli'
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub[cli]) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[cli]) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[cli]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[cli]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[cli]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub[cli]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub[cli]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.20.0->huggingface_hub[cli]) (0.1.2)
# Downloading huggingface_hub-1.16.1-py3-none-any.whl (668 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.2/668.2 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
# Successfully installed huggingface_hub-1.16.1

# %%
from huggingface_hub import login

login()  # paste your HF to|
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#Load huggingface
# installations

# !pip install -U fiftyone
# !pip install huggingface_hub[hf_xet]
# !pip install --upgrade huggingface_hub
# Out:
# Collecting fiftyone
#   Downloading fiftyone-1.15.0-py3-none-any.whl.metadata (23 kB)
# Collecting Deprecated (from fiftyone)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fiftyone) (26.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from fiftyone) (75.2.0)
# Requirement already satisfied: aiofiles<26,>=20 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (24.1.0)
# Collecting argcomplete<4,>=2 (from fiftyone)
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Collecting async_lru<3,>=2 (from fiftyone)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: beautifulsoup4<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.13.5)
# Collecting boto3<2,>=1 (from fiftyone)
#   Downloading boto3-1.43.14-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cachetools<7,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (6.2.6)
# Collecting dacite<2,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: dill<0.5,>=0.1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.3.8)
# Collecting exceptiongroup<2,>=1 (from fiftyone)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting ftfy<7,>=4 (from fiftyone)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: humanize<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.15.0)
# Collecting hypercorn<0.19,>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.18.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: Jinja2<4,>=3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.1.6)
# Requirement already satisfied: jsonpatch<2,>=1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.33)
# Collecting mongoengine~=0.29.1 (from fiftyone)
#   Downloading mongoengine-0.29.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting motor~=3.6.0 (from fiftyone)
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: Pillow!=11.2.*,>=6.2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (11.3.0)
# Collecting plotly<7,>=6.1.1 (from fiftyone)
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pprintpp<0.5,>=0.1 (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting protobuf==6.33.5 (from fiftyone)
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: psutil<8,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (5.9.5)
# Collecting pydash<9,>=6 (from fiftyone)
#   Downloading pydash-8.0.6-py3-none-any.whl.metadata (3.4 kB)
# Collecting pymongo~=4.9.2 (from fiftyone)
#   Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2025.2)
# Requirement already satisfied: PyYAML<7,>=4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (6.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2025.11.3)
# Collecting retrying<2,>=1 (from fiftyone)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: sse-starlette<4,>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.3.4)
# Requirement already satisfied: starlette<0.53,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.52.1)
# Collecting strawberry-graphql<0.292.0,>=0.262.4 (from fiftyone)
#   Downloading strawberry_graphql-0.291.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tabulate<0.10,>=0.7 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: tqdm<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.67.3)
# Collecting xmltodict<2,>=1 (from fiftyone)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2.0.2)
# Requirement already satisfied: opencv-python-headless<5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.13.0.92)
# Requirement already satisfied: pandas<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2.2.2)
# Requirement already satisfied: rtree<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.4.1)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.6.1)
# Requirement already satisfied: scikit-image<1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.16.3)
# Collecting fiftyone-brain<0.22,>=0.21.6 (from fiftyone)
#   Downloading fiftyone_brain-0.21.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-1.4.1.tar.gz (8.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.16,>=0.15.3 (from fiftyone)
#   Downloading voxel51_eta-0.15.5-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=2->fiftyone) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=2->fiftyone) (4.15.0)
# Collecting botocore<1.44.0,>=1.43.14 (from boto3<2,>=1->fiftyone)
#   Downloading botocore-1.43.14-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1->fiftyone)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.18.0,>=0.17.0 (from boto3<2,>=1->fiftyone)
#   Downloading s3transfer-0.17.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<7,>=4->fiftyone) (0.6.0)
# Requirement already satisfied: h11 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone) (0.16.0)
# Requirement already satisfied: h2>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone) (4.3.0)
# Collecting priority (from hypercorn<0.19,>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14.0 (from hypercorn<0.19,>=0.13.2->fiftyone)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2<4,>=3->fiftyone) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2,>=1->fiftyone) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4->fiftyone) (2026.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7,>=6.1.1->fiftyone) (2.20.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->fiftyone) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->fiftyone) (3.6.0)
# Requirement already satisfied: anyio>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from sse-starlette<4,>=0.10.3->fiftyone) (4.13.0)
# Collecting cross-web>=0.4.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone)
#   Downloading cross_web-0.7.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone)
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httpx>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting paramiko<4,>=3 (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading paramiko-3.5.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting py7zr (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading py7zr-1.1.0-py3-none-any.whl.metadata (17 kB)
# Collecting rarfile (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.32.4)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (5.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.5.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated->fiftyone) (2.1.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.7.0->sse-starlette<4,>=0.10.3->fiftyone) (3.13)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.9)
# Collecting bcrypt>=3.2 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.12/dist-packages (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (43.0.3)
# Collecting pynacl>=1.5 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4->fiftyone) (1.17.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->voxel51-eta<0.16,>=0.15.3->fiftyone) (26.1.0)
# Collecting texttable (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone) (1.2.0)
# Collecting backports.zstd>=1.0.0 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading backports_zstd-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.8 kB)
# Collecting pyppmd>=1.3.1 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting pybcj>=1.0.6 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64>=1.0.4 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.3->paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.0)
# Downloading fiftyone-1.15.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 126.9 MB/s eta 0:00:00
# Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 kB 37.1 MB/s eta 0:00:00
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 5.6 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading boto3-1.43.14-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 19.4 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading fiftyone_brain-0.21.6-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 15.6 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.8 MB/s eta 0:00:00
# Downloading hypercorn-0.18.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.9 MB/s eta 0:00:00
# Downloading mongoengine-0.29.3-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 15.0 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.8 MB/s eta 0:00:00
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 159.7 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 14.0 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.3 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading sseclient_py-1.9.0-py3-none-any.whl (8.4 kB)
# Downloading strawberry_graphql-0.291.3-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 36.2 MB/s eta 0:00:00
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.15.5-py2.py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.9/935.9 kB 72.3 MB/s eta 0:00:00
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading botocore-1.43.14-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 142.2 MB/s eta 0:00:00
# Downloading cross_web-0.7.0-py3-none-any.whl (25 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 37.4 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 26.4 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading paramiko-3.5.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 27.3 MB/s eta 0:00:00
# Downloading s3transfer-0.17.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-1.1.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 9.0 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading backports_zstd-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.3/495.3 kB 53.7 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 32.8 MB/s eta 0:00:00
# Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 13.1 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 6.5 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 91.6 MB/s eta 0:00:00
# Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 19.1 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fiftyone-db
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.4.1-py3-none-manylinux1_x86_64.whl size=50655255 sha256=f7013e4a78bc83214b35b4775b7e9fc3c317a4298f09778362a64c6b0ec56547
#   Stored in directory: /root/.cache/pip/wheels/fc/06/06/0eb7530b99c4934bf36390769cff3f0052fd04f50f390d5c8b
# Successfully built fiftyone-db
# Installing collected packages: texttable, pprintpp, xmltodict, wsproto, sseclient-py, retrying, rarfile, pyppmd, pydash, pybcj, protobuf, priority, plotly, multivolumefile, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, exceptiongroup, dnspython, Deprecated, dacite, cross-web, bcrypt, backports.zstd, async_lru, argcomplete, strawberry-graphql, pynacl, pymongo, py7zr, hypercorn, botocore, universal-analytics-python3, s3transfer, paramiko, motor, mongoengine, fiftyone-brain, voxel51-eta, boto3, fiftyone
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.5 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.5 which is incompatible.
# Successfully installed Deprecated-1.3.1 argcomplete-3.6.3 async_lru-2.3.0 backports.zstd-1.5.0 bcrypt-5.0.0 boto3-1.43.14 botocore-1.43.14 cross-web-0.7.0 dacite-1.9.2 dnspython-2.8.0 exceptiongroup-1.3.1 fiftyone-1.15.0 fiftyone-brain-0.21.6 fiftyone-db-1.4.1 ftfy-6.3.1 graphql-core-3.2.8 hypercorn-0.18.0 inflate64-1.0.4 jmespath-1.1.0 jsonlines-4.0.0 mongoengine-0.29.3 motor-3.6.1 multivolumefile-0.2.3 paramiko-3.5.1 plotly-6.7.0 pprintpp-0.4.0 priority-2.0.0 protobuf-6.33.5 py7zr-1.1.0 pybcj-1.0.7 pydash-8.0.6 pymongo-4.9.2 pynacl-1.6.2 pyppmd-1.3.1 rarfile-4.2 retrying-1.4.2 s3transfer-0.17.0 sseclient-py-1.9.0 strawberry-graphql-0.291.3 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.15.5 wsproto-1.3.2 xmltodict-1.0.4
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[hf_xet]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[hf_xet]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[hf_xet]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[hf_xet]) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub[hf_xet]) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[hf_xet]) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[hf_xet]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[hf_xet]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub[hf_xet]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub[hf_xet]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub[hf_xet]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.20.0->huggingface_hub[hf_xet]) (0.1.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.20.0->huggingface_hub) (0.1.2)

# %%
#load voxel 51 SLAKE
import fiftyone as fo

from fiftyone.utils.huggingface import load_from_hub


  # Load the dataset

  # Note: other available arguments include 'max_samples', etc

dataset = load_from_hub("Voxel51/SLAKE")
# Out:
# Downloading config file fiftyone.yml from Voxel51/SLAKE
# INFO:fiftyone.utils.huggingface:Downloading config file fiftyone.yml from Voxel51/SLAKE
# Loading dataset
# INFO:fiftyone.utils.huggingface:Loading dataset
# Importing samples...
# INFO:fiftyone.utils.data.importers:Importing samples...
#  100% |█████████████████| 642/642 [36.5ms elapsed, 0s remaining, 17.6K samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 642/642 [36.5ms elapsed, 0s remaining, 17.6K samples/s]
# Migrating dataset 'Voxel51/SLAKE' to v1.15.0
# INFO:fiftyone.migrations.runner:Migrating dataset 'Voxel51/SLAKE' to v1.15.0

# %%
# !pip install 'transformers>=4.41.0' 'tokenizers>=0.19.0'
# Out:
# Requirement already satisfied: transformers>=4.41.0 in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: tokenizers>=0.19.0 in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (1.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (0.24.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41.0) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.41.0) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.41.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.41.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.41.0) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.41.0) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers>=4.41.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers>=4.41.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers>=4.41.0) (0.1.2)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# --- Load LLaMA
llm_model_name = "meta-llama/Llama-3.1-8B-Instruct"  # or your variant
llm_tokenizer = AutoTokenizer.from_pretrained(llm_model_name)
llm_model = AutoModelForCausalLM.from_pretrained(
    llm_model_name,
    dtype=torch.bfloat16  # optional, if GPU supports
)
llm_model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
llm_model.to(device)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
# --- Callable function
def run_llama(messages, max_new_tokens=300):
    inputs = llm_tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    ).to(device)

    outputs = llm_model.generate(**inputs, max_new_tokens=max_new_tokens, pad_token_id=llm_tokenizer.eos_token_id)

    return llm_tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:], skip_special_tokens=True
    )

# %%
from open_clip import create_model_from_pretrained, get_tokenizer # works on open-clip-torch>=2.23.0, timm>=0.9.8

model, preprocess = create_model_from_pretrained('hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224')
tokenizer = get_tokenizer('hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224')
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
import torch
from open_clip import create_model_and_transforms, get_tokenizer
from PIL import Image

class BiomedCLIPConfirm:
    def __init__(self,
                 model_name="hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224",
                 device=None,
                 single_rationale_threshold=20.0):
        """
        Initialize BiomedCLIP confirm module.

        Args:
            single_rationale_threshold: float, threshold for accepting a single rationale
        """
        self.device = device or (torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu"))

        # Load model, tokenizer, and preprocessing transforms
        self.model, _, self.preprocess = create_model_and_transforms(model_name)
        self.tokenizer = get_tokenizer(model_name)

        self.model.to(self.device)
        self.model.eval()
        self.context_length = 256  # Max tokens for rationales
        self.single_rationale_threshold = single_rationale_threshold

    def score_rationales(self, image, rationales, template="This is a generated rationale for an image:"):
        """
        Compute similarity scores between image and list of rationales.
        Returns a tensor of scores.
        """
        # Preprocess image
        if not isinstance(image, torch.Tensor):
            image = self.preprocess(image).unsqueeze(0)  # add batch dim
        image = image.to(self.device)

        # Tokenize rationales
        texts = self.tokenizer([template + r for r in rationales],
                               context_length=self.context_length).to(self.device)

        # Compute embeddings
        with torch.no_grad():
            image_features, text_features, logit_scale = self.model(image, texts)
            scores = (image_features @ text_features.T).squeeze(0) * logit_scale

        return scores

    def confirm(self, image, rationales, threshold_method='percentile',
                top_pct=0.3, epsilon=0.05, manual_thresh=None):
        """
        Accept/reject rationales based on similarity thresholds.

        threshold_method: 'percentile', 'relative_max', or 'manual'
        manual_thresh: float, only used if threshold_method='manual'
        """
        scores = self.score_rationales(image, rationales)

        if threshold_method == 'percentile':
            thresh = torch.quantile(scores, 1 - top_pct)
        elif threshold_method == 'relative_max':
            thresh = scores.max() - epsilon
        elif threshold_method == 'manual':
            if manual_thresh is None:
                raise ValueError("Must provide manual_thresh when using threshold_method='manual'")
            thresh = manual_thresh
        else:
            raise ValueError("threshold_method must be 'percentile', 'relative_max', or 'manual'")

        accepted = [r for r, s in zip(rationales, scores) if s >= thresh]
        rejected = [r for r, s in zip(rationales, scores) if s < thresh]

        return accepted, rejected, scores, float(thresh)

# %%
# Initialize
confirm_module = BiomedCLIPConfirm()

# %%
def med_vctp(image_path, question, examples5, gCaption, rCaption = None):
    # Define messages
    message1 = f"""This is the medical question at hand about a specific image: {question}. Here is a global caption describing the entire image: {gCaption}.
    Here are all regional captions for the same image that describe a certain region summarized by the label next to it: {rCaption}
    Your goal is to identify what specific information from the global and regional captions provided are useful for understanding and answering the question.
    Create a summary of the specific information that is concise yet informational and relevant to the question, so that it can be answered properly later.
    The summary can be 4 sentences maximum.
    Make the summary informative enough so that someone without access to the image can use the summary to answer the question, but make it concise enough so that someone can understand it properly"""
    messages1 = [
    {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
    {"role": "user", "content": message1}
    ]

    # Generate concepts & information
    responseConcepts = run_llama(messages1, max_new_tokens = 400)
    #print('1' + responseConcepts)
    message2 = f"""Here is a summary of the relevant concepts and information useful to answering the question at hand: {responseConcepts}.
    Here is the question that the summary provides useful information to answer: {question}
    The answer to this question is a single word, yes or no.
    Provided below is a list of 5 different reasoning examples, consisting of an answer to the question and a rationale quickly explaining why the answer was chosen and is correct.
    {examples5}
    Use only the summary provided to generate the rationale. Do not infer or introduce any information not in the summary.
    Use the summary intended to help create the rationale and answer the question. Separate the rationale and answer by 3 hashtags, ###.
    The rationale should be 1-2 sentences maximum and concise, and the answer should be yes or no to answer the question.
    Make sure the rationale is written so that someone can use it to immediately answer the question given at hand"""
    messages2 = [
    {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
    {"role": "user", "content": message2}
    ]
    # Generate rationale & answer (Conclusion)
    conclusion = run_llama(messages2 , max_new_tokens = 400)
    #print('2' + conclusion)
    if '###' in conclusion:
        parts = conclusion.split('###')
        rationale = parts[0].strip()
        answer = parts[-1].strip()  # last part should be the yes/no

    else:
      rationale, answer = conclusion, 'unknown'

    refined_rationale = rationaleCheck(question, responseConcepts, image_path, rationale, examples5)
    #print('3' + refined_rationale)
    refined_answer = run_llama(messages = [
    {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
    {"role": "user", "content": f"""Here is a rationale to a specific question: {refined_rationale}.
    Here is the question: {question}.
    Use the rationale to give a yes/no answer to the question. Output should be one word."""}
    ])
    #print('4' + refined_answer)

    return refined_rationale, refined_answer

# %%
def rationaleCheck(question, information, image_path, rationale, examples, maxIter=3, threshold_method='manual', manual_thresh=30):
    openedImage = Image.open(image_path)

    modRationale = rationale
    best_rationale = modRationale
    best_score = -1.0  # initialize as very low

    for x in range(maxIter):

        improvMsg = [
            {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
            {"role": "user", "content": f"""Review this rationale: {modRationale} you generated for the question: {question}.
            If it uses irrelevant or inaccurate information, remake it based strictly on the provided information base: {information}.
Try to remake the rationale based off the information provided, and the question mentioned earlier.
Make sure that you strictly utilize information directly from the information base to generate a conclusion with a concise rationale.
Again, here are the 5 different reasoning examples consisting of an answer to the question and a rationale quickly explaining why the answer was chosen and is correct:
{examples}
**Do not use any factual information from these examples; rely solely on the summary provided.**
Make sure the rationales you generate for the given question at hand that use the information base provided earlier are 1-2 sentences maximum, written so that someone can use it to immediately answer the question"""
            }
        ]

        accepted, rejected, scores, thresh = confirm_module.confirm(
            openedImage, [modRationale], threshold_method, top_pct=0.5, manual_thresh=manual_thresh
        )

        # unwrap single-value tensor into float
        if isinstance(scores, torch.Tensor):
            current_score = float(scores.item())
        else:
            current_score = float(scores)

        # Track the highest scoring rationale
        if current_score > best_score:
            best_score = current_score
            best_rationale = modRationale

        if accepted:
            return modRationale
        else:
            modRationale = run_llama(improvMsg)

    # Fallback: if no rationale passed the threshold, return the one with highest score
    return best_rationale

# %%
examples5 = """
Rationale: The image shows clear bilateral pulmonary infiltrates, consistent with fluid accumulation in both lungs. This pattern strongly indicates the condition is present. ### yes
Rationale: The enlarged heart silhouette is evident, with no signs of acute pulmonary edema. Therefore, the specific cardiac abnormality is not indicated. ### no
Rationale: The lesion appears well-circumscribed and lacks surrounding tissue invasion, suggesting it is benign. ### no
Rationale: There is a visible opacity in the lower lobe with associated pleural effusion, which supports the diagnosis. ### yes
Rationale: The imaging shows normal organ contours and no abnormal densities; there are no indicators for the condition in question. ### no"""

# %%
import string

def normalize(ans):
    return ans.strip().lower().strip(string.punctuation)

# %%
normal = normalize("YEs.   ")
print(normal)
# Out:
# yes

# %%
import json

# Load JSON files
with open("close_bbox.json") as f:
    close_bbox = json.load(f)

with open("raw_images.json") as f:
    raw_images = json.load(f)

with open("gCaptions_0 (1).json") as f:
    gCaptions = json.load(f)

with open("rCaptions1_0.json") as f:
    rCaptions = json.load(f)

# Create dictionaries for faster lookup
image_id_to_path = {item['image_id']: item['image_path'] for item in raw_images}
image_id_to_gcaption = {item['image_id']: item['caption'] for item in gCaptions}

# Organize regional captions by image_id
from collections import defaultdict
image_id_to_rcaptions = defaultdict(list)
for item in rCaptions:
    image_id_to_rcaptions[item['image_id']].append(item)
s  for rc in rCaptions_list:
        rCaption_str += f"Label: {rc['label']}, Caption: {rc['caption'].strip()}. "

    # Strip final whitespace
    rCaption_str = rCaption_str.strip()

    # Now you have all components for the VCTP function
    rationaleOut, answerOut = med_vctp(image_path, question, examples5, gCaption, rCaption_str)
    if normalize(answerOut) == answer.lower():
        correct+=1
    else:
        pass
    total+=1
    if total%100 == 0:
        print(f"100 done so far, {correct} correct and {total} total questions passed")
print(f"Total correct = {correct}")
print(f"Total = {total}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7736/1265670771.py in <cell line: 0>()
#      50
#      51     # Now you have all components for the VCTP function
# ---> 52     rationaleOut, answerOut = med_vctp(image_path, question, examples5, gCaption, rCaption_str)
#      53     if normalize(answerOut) == answer.lower():
#      54         correct+=1
#
# /tmp/ipykernel_7736/2695194262.py in med_vctp(image_path, question, examples5, gCaption, rCaption)
#      39       rationale, answer = conclusion, 'unknown'
#      40
# ---> 41     refined_rationale = rationaleCheck(question, responseConcepts, image_path, rationale, examples5)
#      42     #print('3' + refined_rationale)
#      43     refined_answer = run_llama(messages = [
#
# /tmp/ipykernel_7736/520329733.py in rationaleCheck(question, information, image_path, rationale, examples, maxIter, threshold_method, manual_thresh)
#      39             return modRationale
#      40         else:
# ---> 41             modRationale = run_llama(improvMsg)
#      42
#      43     # Fallback: if no rationale passed the threshold, return the one with highest score
#
# /tmp/ipykernel_7736/478114077.py in run_llama(messages, max_new_tokens)
#       9     ).to(device)
#      10
# ---> 11     outputs = llm_model.generate(**inputs, max_new_tokens=max_new_tokens, pad_token_id=llm_tokenizer.eos_token_id)
#      12
#      13     return llm_tokenizer.decode(
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2578
#    2579         # 9. Call generation mode
# -> 2580         result = decoding_method(
#    2581             self,
#    2582             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2785                 )
#    2786                 with self._optimize_model_for_decode():
# -> 2787                     outputs = model_forward(**model_inputs, return_dict=True)
#    2788             prefill_consumed = True
#    2789             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     901         if return_dict_passed is not None:
#     902             return_dict = return_dict_passed
# --> 903         output = func(self, *args, **kwargs)
#     904         if not return_dict and not isinstance(output, tuple):
#     905             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, logits_to_keep, **kwargs)
#     472         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     473         ```"""
# --> 474         outputs: BaseModelOutputWithPast = self.model(
#     475             input_ids=input_ids,
#     476             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1030                     output = func(self, *args, **kwargs)
#    1031             else:
# -> 1032                 output = func(self, *args, **kwargs)
#    1033         # Restore original config value
#    1034         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/output_capturing.py in wrapper(self, *args, **kwargs)
#     250             # Run the forward
#     251             try:
# --> 252                 outputs = func(self, *args, **kwargs)
#     253             # Reset the states
#     254             finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     409
#     410         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 411             hidden_states = decoder_layer(
#     412                 hidden_states,
#     413                 attention_mask=causal_mask,
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     312     ) -> torch.Tensor:
#     313         residual = hidden_states
# --> 314         hidden_states = self.input_layernorm(hidden_states)
#     315         # Self Attention
#     316         hidden_states, _ = self.self_attn(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states)
#      65         variance = hidden_states.pow(2).mean(-1, keepdim=True)
#      66         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
# ---> 67         return self.weight * hidden_states.to(input_dtype)
#      68
#      69     def extra_repr(self):
#
# KeyboardInterrupt:

# %%
print(correct)

# %%
print(total)

# %%
def med_vctp1(image_path, question, examples5, gCaption, rCaption = None):
    # Define messages
    message1 = f"""This is the medical question at hand about a specific image: {question}. Here is a global caption describing the entire image: {gCaption}.
    Here are all regional captions for the same image that describe a certain region summarized by the label next to it: {rCaption}
    Your goal is to identify what specific information from the global and regional captions provided are useful for understanding and answering the question.
    Create a summary of the specific information that is concise yet informational and relevant to the question, so that it can be answered properly later.
    The summary can be 4 sentences maximum.
    Make the summary informative enough so that someone without access to the image can use the summary to answer the question, but make it concise enough so that someone can understand it properly"""
    messages1 = [
    {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
    {"role": "user", "content": message1}
    ]

    # Generate concepts & information
    responseConcepts = run_llama(messages1, max_new_tokens = 400)
    #print('1' + responseConcepts)
    message2 = f"""Here is a summary of the relevant concepts and information useful to answering the question at hand: {responseConcepts}.
    Here is the question that the summary provides useful information to answer: {question}
    The answer to this question is a single word, yes or no.
    Provided below is a list of 5 different reasoning examples, consisting of an answer to the question and a rationale quickly explaining why the answer was chosen and is correct.
    {examples5}
    Use only the summary provided to generate the rationale. Do not infer or introduce any information not in the summary.
    Use the summary intended to help create the rationale and answer the question. Separate the rationale and answer by 3 hashtags, ###.
    The rationale should be 1-2 sentences maximum and concise, and the answer should be yes or no to answer the question.
    Make sure the rationale is written so that someone can use it to immediately answer the question given at hand"""
    messages2 = [
    {"role": "system", "content": "You are a medical visual reasoning assistant. Base your reasoning on provided medical image context and stay visually grounded and medically accurate."},
    {"role": "user", "content": message2}
    ]
    # Generate rationale & answer (Conclusion)
    conclusion = run_llama(messages2 , max_new_tokens = 400)
    rationale, answer = parse_vctp_output(conclusion)
    #print('2' + conclusion)
    return rationale, answer

# %%
def parse_vctp_output(conclusion):
    # Lowercase for normalization
    conclusion = conclusion.lower().strip()

    # Remove leading numbers like "2" or "2###"
    conclusion = conclusion.lstrip("0123456789. ").replace("2###", "").strip()

    # Extract yes/no
    if conclusion.startswith("yes"):
        answer = "yes"
        rationale = conclusion[len("yes"):].strip(" \n#")
    elif conclusion.startswith("no"):
        answer = "no"
        rationale = conclusion[len("no"):].strip(" \n#")
    else:
        # fallback: search for 'yes' or 'no' in the first 20 chars
        if "yes" in conclusion[:20]:
            answer = "yes"
        elif "no" in conclusion[:20]:
            answer = "no"
        else:
            answer = "unknown"
        rationale = conclusion
    return rationale, answer

# %%
import json

# Load JSON files
with open("close_bbox.json") as f:
    close_bbox = json.load(f)

with open("raw_images.json") as f:
    raw_images = json.load(f)

with open("gCaptions_1.json") as f:
    gCaptions = json.load(f)

with open("rCaptions_1.json") as f:
    rCaptions = json.load(f)

# Create dictionaries for faster lookup
image_id_to_path = {item['image_id']: item['image_path'] for item in raw_images}
image_id_to_gcaption = {item['image_id']: item['caption'] for item in gCaptions}

# Organize regional captions by image_id
from collections import defaultdict
image_id_to_rcaptions = defaultdict(list)
for item in rCaptions:
    image_id_to_rcaptions[item['image_id']].append(item)

# Loop through close_bbox
correct = 0
total = 0
for entry in close_bbox:
    image_id = entry['image_id']
    question = entry['question']
    answer = entry.get('answer', None)  # optional

    # Get image path
    image_path = image_id_to_path.get(image_id, None)

    # Get global caption
    gCaption = image_id_to_gcaption.get(image_id, "")

    # Get all regional captions
    rCaptions_list = image_id_to_rcaptions.get(image_id, [])

    # Combine regional captions into one string
    rCaption_str = ""
    for rc in rCaptions_list:
        rCaption_str += f"Label: {rc['label']}, Caption: {rc['caption'].strip()}. "

    # Strip final whitespace
    rCaption_str = rCaption_str.strip()

    # Now you have all components for the VCTP function
    rationaleOut, answerOut = med_vctp1(image_path, question, examples5, gCaption, rCaption_str)
    if normalize(answerOut) == answer.lower():
        correct+=1
    else:
        pass
    total+=1
    if total%100 == 0:
        print(f"100 done so far, {correct} correct and {total} total questions passed")
print(f"Total correct = {correct}")
print(f"Total = {total}")

# %%
print(correct)

# %%
print(total)
